# %%
# %load_ext autoreload
# %autoreload 2
import sys
# map folder using sys
#sys.path.append('../')
import pandas as pd
from galgoz import DATA_FOLDER, Galgoz
from galgoz.utils import set_data_index_and_time_str
from galgoz.indicators import SuperTrend
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = pd.read_pickle(DATA_FOLDER / "GBP_JPY_H1.pkl")
data = set_data_index_and_time_str(data)

# %%
st = SuperTrend(data, 10, 3).output

# %%
gz = Galgoz()

# %%
df_plot = data.iloc[-3000:].copy()
ind = gz.indicators(SuperTrend(df_plot, 21, 6))
fig = gz.plot_candles(df_plot, indicators=ind, show=True)
