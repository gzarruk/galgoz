# %%
# %load_ext autoreload
# %autoreload 2
import sys
# map folder using sys
sys.path.append('../')
from galgoz.backtesting import Backtest
from galgoz.indicators import WPR, SG, MFI, HMA, Hline
from galgoz import DATA_FOLDER, Galgoz
import pandas as pd
import numpy as np
import plotly.graph_objects as go
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
bt = Backtest()
bt.run()
# Out:
# Initializing backtest for Galgoz Standard
# No indicators provided. Using default indicators: Savitzky-Golay filter and Williams %R.
# ---
# Running backtest on Galgoz Standard
# ---
# BUY signals generated: 55
# SELL signals generated: 55
# Backtest completed in 2.49 seconds and evaluated 4500 time-steps

# %%
gz = Galgoz()
indicators=gz.indicators(
    MFI(bt.data, window=11), 
    Hline(bt.data, yvalue=75), 
    Hline(bt.data, yvalue=25), 
    HMA(bt.data, window=150))
fig = gz.plot_candles(bt.data, indicators=indicators, show=False)
# Plot the BUY signals, labelled as 1 in the 'signals' column. Use the mid_l price to plot the signal and use a green triangle up marker.
fig.add_trace(go.Scatter(x=bt.data.time_str[bt.data['signals'] == 1], y=bt.data['mid_l'][bt.data['signals'] == 1], mode='markers', marker=dict(color='green', symbol='triangle-up', size=15), customdata=bt.data['signals'][bt.data['signals'] == 1], hovertemplate='Buy Signal', showlegend=False))
# Now SELL signals, labelled as -1 in the 'signals' column. Use the mid_l price to plot the signal and use a red triangle down marker.
fig.add_trace(go.Scatter(x=bt.data.time_str[bt.data['signals'] == -1], y=bt.data['mid_l'][bt.data['signals'] == -1], mode='markers', marker=dict(color='red', symbol='triangle-down', size=15), customdata=bt.data['signals'][bt.data['signals'] == -1], hovertemplate='Sell Signal', showlegend=False))

# %%
bt.data.head()
# Out:
#                             index  complete   volume    mid_o    mid_h  \
# time
# 2024-03-11 11:00:00+00:00  121920         1   5759.0  188.428  188.504
# 2024-03-11 12:00:00+00:00  121921         1  10383.0  188.457  188.596
# 2024-03-11 13:00:00+00:00  121922         1  11120.0  188.295  188.476
# 2024-03-11 14:00:00+00:00  121923         1  11474.0  188.474  188.603
# 2024-03-11 15:00:00+00:00  121924         1  12007.0  188.385  188.428
#
#                              mid_l    mid_c            time_str  HMA  MFI  \
# time
# 2024-03-11 11:00:00+00:00  188.383  188.455   Mar 11, '24 11:00  NaN  NaN
# 2024-03-11 12:00:00+00:00  188.280  188.294   Mar 11, '24 12:00  NaN  NaN
# 2024-03-11 13:00:00+00:00  188.253  188.473   Mar 11, '24 13:00  NaN  NaN
# 2024-03-11 14:00:00+00:00  188.372  188.384   Mar 11, '24 14:00  NaN  NaN
# 2024-03-11 15:00:00+00:00  187.963  188.058   Mar 11, '24 15:00  NaN  NaN
#
#                            signals  entry  stop_loss  take_profit
# time
# 2024-03-11 11:00:00+00:00      NaN    NaN        NaN          NaN
# 2024-03-11 12:00:00+00:00      NaN    NaN        NaN          NaN
# 2024-03-11 13:00:00+00:00      NaN    NaN        NaN          NaN
# 2024-03-11 14:00:00+00:00      NaN    NaN        NaN          NaN
# 2024-03-11 15:00:00+00:00      NaN    NaN        NaN          NaN
